# %% [markdown]
# <a href="https://colab.research.google.com/github/ritikkr99/BankNote-Authentication-Model/blob/main/Pandas_lesson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv('/content/sample_data/california_housing_test.csv')
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# if we want to remove the columns names, the entire table is called dataframe

# %%
pd.read_csv('/content/sample_data/california_housing_test.csv',header = None)
# Out:
#                 0          1                   2            3               4  \
# 0       longitude   latitude  housing_median_age  total_rooms  total_bedrooms
# 1     -122.050000  37.370000           27.000000  3885.000000      661.000000
# 2     -118.300000  34.260000           43.000000  1510.000000      310.000000
# 3     -117.810000  33.780000           27.000000  3589.000000      507.000000
# 4     -118.360000  33.820000           28.000000    67.000000       15.000000
# ...           ...        ...                 ...          ...             ...
# 2996  -119.860000  34.420000           23.000000  1450.000000      642.000000
# 2997  -118.140000  34.060000           27.000000  5257.000000     1082.000000
# 2998  -119.700000  36.300000           10.000000   956.000000      201.000000
# 2999  -117.120000  34.100000           40.000000    96.000000       14.000000
# 3000  -119.630000  34.420000           42.000000  1765.000000      263.000000
#
# ...

# %% [markdown]
# if we want to change the column names

# %%
pd.read_csv('/content/sample_data/california_housing_test.csv',names=['a','b'])
# Out:
#                                                                                                          a  \
# longitude   latitude  housing_median_age total_rooms total_bedrooms population  households   median_income
# -122.050000 37.370000 27.000000          3885.000000 661.000000     1537.000000 606.000000        6.608500
# -118.300000 34.260000 43.000000          1510.000000 310.000000     809.000000  277.000000        3.599000
# -117.810000 33.780000 27.000000          3589.000000 507.000000     1484.000000 495.000000        5.793400
# -118.360000 33.820000 28.000000          67.000000   15.000000      49.000000   11.000000         6.135900
# ...                                                                                                    ...
# -119.860000 34.420000 23.000000          1450.000000 642.000000     1258.000000 607.000000        1.179000
# -118.140000 34.060000 27.000000          5257.000000 1082.000000    3496.000000 1036.000000       3.390600
# ...

# %% [markdown]
# to seperate the data we use **sep=**, by defalut the seperator is comma

# %%
pd.read_csv('/content/sample_data/california_housing_train.csv')
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# if you want to skip rows use **skiprows**

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv',skiprows=[1,4])

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.47     34.40                19.0       7650.0          1901.0
# 1        -114.56     33.69                17.0        720.0           174.0
# 2        -114.57     33.57                20.0       1454.0           326.0
# 3        -114.58     33.63                29.0       1387.0           236.0
# 4        -114.58     33.61                25.0       2907.0           680.0
# ...          ...       ...                 ...          ...             ...
# 16993    -124.26     40.58                52.0       2217.0           394.0
# 16994    -124.27     40.69                36.0       2349.0           528.0
# 16995    -124.30     41.84                17.0       2677.0           531.0
# 16996    -124.30     41.80                19.0       2672.0           552.0
# 16997    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# if you want to know number of columns and its type use **df.dtype**,
#
#  if you want to see only columns use **df.columns**

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %% [markdown]
# **head** show us first five records of the dataframe(df),
#
# **tail** will show you the bottom 5 record of the df
# df.head

# %%
df.head
# Out:
# <bound method NDFrame.head of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.47     34.40                19.0       7650.0          1901.0
# 1        -114.56     33.69                17.0        720.0           174.0
# 2        -114.57     33.57                20.0       1454.0           326.0
# 3        -114.58     33.63                29.0       1387.0           236.0
# 4        -114.58     33.61                25.0       2907.0           680.0
# ...          ...       ...                 ...          ...             ...
# 16993    -124.26     40.58                52.0       2217.0           394.0
# 16994    -124.27     40.69                36.0       2349.0           528.0
# 16995    -124.30     41.84                17.0       2677.0           531.0
# 16996    -124.30     41.80                19.0       2672.0           552.0
# 16997    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.tail(3)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.30     41.84                17.0       2677.0           531.0
# 16996    -124.30     41.80                19.0       2672.0           552.0
# 16997    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995      1244.0       456.0         3.0313            103600.0
# 16996      1298.0       478.0         1.9797             85800.0
# 16997       806.0       270.0         3.0147             94600.0

# %% [markdown]
# if you want the selected columns use

# %%
df['population']
# Out:
# 0        1129.0
# 1         333.0
# 2         624.0
# 3         671.0
# 4        1841.0
#           ...
# 16993     907.0
# 16994    1194.0
# 16995    1244.0
# 16996    1298.0
# 16997     806.0
# Name: population, Length: 16998, dtype: float64

# %% [markdown]
# there are two things that exits as datatypes in pandas, first is dataframes(a complete tabular structure) and second is series(kind of list)

# %% [markdown]
# if you want multiple columns to print

# %%
df[['population','households']]
# Out:
#        population  households
# 0          1129.0       463.0
# 1           333.0       117.0
# 2           624.0       262.0
# 3           671.0       239.0
# 4          1841.0       633.0
# ...           ...         ...
# 16993       907.0       369.0
# 16994      1194.0       465.0
# 16995      1244.0       456.0
# 16996      1298.0       478.0
# 16997       806.0       270.0
#
# [16998 rows x 2 columns]

# %% [markdown]
# if you want a specific sheet you have to define it as **sheet_name**

# %%
pd.read_excel('/content/sample_data/LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx',sheet_name=1)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# ...

# %%
df1 = pd.ExcelFile('/content/sample_data/LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx')

# %%
df1.sheet_names
# Out:
# ['Create Portfolio',
#  'Introduction',
#  'Create your instrument universe',
#  'Add your take on balances',
#  'Create your test environment',
#  'Make live trades in production',
#  'Add some test transactions',
#  'Inputs']

# %% [markdown]
# if you want to get data from github, then click on raw and then copy the page url
# ![Screenshot (69).png](data:image/png;base64,...)![Screenshot (68).png](data:image/png;base64,...)

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
